# %%
install.packages("stylo")
# Out:
# also installing the dependencies ‘Matrix’, ‘nlme’, ‘Rcpp’, ‘cluster’, ‘survival’, ‘MASS’, ‘tcltk2’, ‘ape’, ‘pamr’, ‘e1071’, ‘class’, ‘lattice’, ‘tsne’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(stylo)
# Out:
# ### stylo version: 0.7.4 ###
#
# If you plan to cite this software (please do!), use the following reference:
#     Eder, M., Rybicki, J. and Kestemont, M. (2016). Stylometry with R:
#     a package for computational text analysis. R Journal 8(1): 107-121.
#     <https://journal.r-project.org/archive/2016/RJ-2016-007/index.html>
#
# To get full BibTeX entry, type: citation("stylo")

# %%
data(galbraith)

# %%
galbraith
# Out:
#                      the       and       to        of        a
# coben_breaker        3.5921994 1.1751078 2.1627238 1.3757359 2.5185999
# coben_dropshot       3.5878361 1.1785435 2.1221613 1.2685983 2.3753589
# coben_fadeaway       3.9313925 1.4454976 2.2004062 1.2130445 2.3064771
# coben_falsemove      3.625411  1.6133386 2.1335329 1.2366884 2.4009913
# coben_goneforgood    3.8340306 1.816723  2.152941  1.1758076 1.961908
# coben_nosecondchance 4.0982934 1.5889666 2.2712554 1.2058633 1.9921373
# coben_tellnoone      4.1015556 1.7901359 2.0306373 1.2463421 2.1763598
# galbraith_cuckoos    4.5230275 2.267404  2.4940058 2.1793966 2.1412831
# lewis_battle         5.0507132 3.4045379 2.1384253 2.1384253 1.9598416
# lewis_caspian        4.8654723 3.5918116 2.1528834 2.1440691 2.1683083
#                      ...       ...       ...       ...       ...
#                      was       I         in        he        said
# ...

# %%
rownames(galbraith)
# Out:
#  [1] "coben_breaker"        "coben_dropshot"       "coben_fadeaway"
#  [4] "coben_falsemove"      "coben_goneforgood"    "coben_nosecondchance"
#  [7] "coben_tellnoone"      "galbraith_cuckoos"    "lewis_battle"
# [10] "lewis_caspian"        "lewis_chair"          "lewis_horse"
# [13] "lewis_lion"           "lewis_nephew"         "lewis_voyage"
# [16] "rowling_casual"       "rowling_chamber"      "rowling_goblet"
# [19] "rowling_hallows"      "rowling_order"        "rowling_prince"
# [22] "rowling_prisoner"     "rowling_stone"        "tolkien_lord1"
# [25] "tolkien_lord2"        "tolkien_lord3"

# %%
stylo(frequencies = galbraith, gui = FALSE)
# Out:
# using current directory...
#
#
#
#
# culling @ 0	available features (words) 3000
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
#
# 100
#
# Processing metadata...
#
#
#
# Assigning plot colors according to file names...
#
#
#
#
#
#
# Function call:
#
# stylo(gui = FALSE, frequencies = galbraith)
#
#
#
# Depending on your chosen options, some results should have been written
#
# into a few files; you should be able to find them in your current
#
# (working) directory. Usually, these include a list of words/features
#
# used to build a table of frequencies, the table itself, a file containing
#
# recent configuration, etc.
#
#
#
# Advanced users: you can pipe the results to a variable, e.g.:
#
# 	 it.deserves.a.nobel.prize = stylo()
#
# this will create a class "it.deserves.a.nobel.prize" containing some presumably
#
# interesting stuff. The class created, you can type, e.g.:
#
# 	 summary(it.deserves.a.nobel.prize)
#
# ...

# %%
write.csv(galbraith, 'galbraith.csv')

# %%
imposters(galbraith)
# Out:
# No candidate set specified; testing the following classes (one at a time):
#
#   coben   lewis   rowling   tolkien
#
#
#
#
# Testing a given candidate against imposters...
#
#
# coben 	 0.37
#
# lewis 	 0
#
# rowling 	 1
#
# tolkien 	 0
#   coben   lewis rowling tolkien
#    0.37    0.00    1.00    0.00
